# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # loading the DataSet

# %%
df=pd.read_csv('hotel_bookings 2.csv')

# %% [markdown]
# # Exploratory Data Analysis and Data Cleaning

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df['reservation_status_date']=df['reservation_status_date'].astype('datetime64[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    print('----/--------------------------------------------------')
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ----/--------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ----/--------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ----/--------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(['agent','company'],axis=1,inplace=True)
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df=df[df['adr']<5000]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# std         0.483167     106.903570           0.707462
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# std                   13.589966                   8.780321
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # Data Analysis and Visualization

# %%
cancelled_prc=df['is_canceled'].value_counts(normalize=True)
print(cancelled_prc)
# Out:
# 0    0.628653
# 1    0.371347
# Name: is_canceled, dtype: float64

# %%
plt.figure(figsize=(5,3))
plt.title('Reservation status count')
plt.bar(['not canceled','Canceled'],df['is_canceled'].value_counts(),width=.4 ,edgecolor='k')
# Out:
# <BarContainer object of 2 artists>

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
plt.figure(figsize=(5,3))

ax1=sns.countplot(x='hotel',hue='is_canceled',data=df,palette='Blues')
plt.title('Reservation Status in Different Hotels')
plt.xlabel('Hotel')
plt.ylabel('Reservation Status')
plt.legend(['not canceled','canceled'])

# %%
resort_hotel=df[df['hotel']=='Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
City_hotel=df[df['hotel']=='City Hotel']
City_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.582918
# 1    0.417082
# Name: is_canceled, dtype: float64

# %%
resort_hotel=df[df['hotel']=='Resort Hotel']

# %%
resort_hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39596 entries, 0 to 40059
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           39596 non-null  object
#  1   is_canceled                     39596 non-null  int64
#  2   lead_time                       39596 non-null  int64
#  3   arrival_date_year               39596 non-null  int64
#  4   arrival_date_month              39596 non-null  object
#  5   arrival_date_week_number        39596 non-null  int64
#  6   arrival_date_day_of_month       39596 non-null  int64
#  7   stays_in_weekend_nights         39596 non-null  int64
#  8   stays_in_week_nights            39596 non-null  int64
#  9   adults                          39596 non-null  int64
#  10  children                        39596 non-null  float64
#  11  babies                          39596 non-null  int64
# ...

# %%
resort_hotel=resort_hotel.groupby(['reservation_status_date'])[['adr']].mean()

# %%
resort_hotel
# Out:
#                                 adr
# reservation_status_date
# 2014-11-18                 0.000000
# 2015-01-01                61.966667
# 2015-01-05               115.363333
# 2015-01-06               133.677143
# 2015-01-07                82.485455
# ...                             ...
# 2017-12-05               103.287534
# 2017-12-06               159.808929
# 2017-12-07               160.306275
# 2017-12-08               212.767222
# 2017-12-09               153.570000
#
# [913 rows x 1 columns]

# %%
City_hotel=City_hotel.groupby(['reservation_status_date'])[['adr']].mean()

# %%
City_hotel
# Out:
#                                 adr
# reservation_status_date
# 2014-10-17                62.800000
# 2015-01-01                62.063158
# 2015-01-05                58.900000
# 2015-01-06                69.216667
# 2015-01-07                82.877500
# ...                             ...
# 2017-12-04               128.755465
# 2017-12-05               124.544536
# 2017-12-06               132.725882
# 2017-12-07               130.473617
# 2017-12-08               142.949080
#
# [864 rows x 1 columns]

# %%
plt.figure(figsize=(20,6))
plt.title('average daily rate in city and resort hotel',size=30)
plt.plot(resort_hotel.index,resort_hotel['adr'],label='Resort Hotel')
plt.plot(City_hotel.index,City_hotel['adr'],label='City Hotel')
plt.legend(fontsize=20)
plt.show()

# %%
df['month'] =df['reservation_status_date'].dt.month
plt.figure(figsize = (16,8))
ax1 = sns.countplot(x = 'month',hue = 'is_canceled',data = df,palette = 'bright')
legend_labels,_ = ax1. get_legend_handles_labels()
plt.title('Reservation status per month',size = 20)
plt.xlabel('month',size=15)
plt.ylabel('number of reservations',size=20)
plt.legend(['not canceled','canceled'],fontsize=20)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot('month','adr',data=df[df['is_canceled']==1].groupby('month')[['adr']].sum().reset_index())
plt.title('Adr per Month',size=30)
plt.xlabel('Month',size=20) 
plt.ylabel('Adr',size=20)
# Out:
# Text(0, 0.5, 'Adr')

# %%
cancelled_data=df[df['is_canceled']==1]
cancelled_data.head()
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 27  Resort Hotel            1         60               2015
# 32  Resort Hotel            1         96               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 8                July                        27                          1
# 9                July                        27                          1
# 10               July                        27                          1
# 27               July                        27                          1
# 32               July                        27                          1
#
#     stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 8                         0                     3       2  ...
# ...

# %%
plt.figure(figsize=(8,8))
top_10_country=cancelled_data['country'].value_counts()[:10]
plt.title('top 10 country with reservation cancelled',size=15)
plt.pie(top_10_country,labels=top_10_country.index,autopct='%.2f%%')
plt.show()

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'month'],
#       dtype='object')

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: market_segment, dtype: float64

# %%
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: market_segment, dtype: float64

# %%
cancelled_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44152 entries, 8 to 117295
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           44152 non-null  object
#  1   is_canceled                     44152 non-null  int64
#  2   lead_time                       44152 non-null  int64
#  3   arrival_date_year               44152 non-null  int64
#  4   arrival_date_month              44152 non-null  object
#  5   arrival_date_week_number        44152 non-null  int64
#  6   arrival_date_day_of_month       44152 non-null  int64
#  7   stays_in_weekend_nights         44152 non-null  int64
#  8   stays_in_week_nights            44152 non-null  int64
#  9   adults                          44152 non-null  int64
#  10  children                        44152 non-null  float64
#  11  babies                          44152 non-null  int64
# ...

# %%
cancelled_df_adr=cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values(by='reservation_status_date',inplace=True)
cancelled_df_adr
# Out:
#     reservation_status_date         adr
# 0                2014-10-17   62.800000
# 1                2014-11-18    0.000000
# 2                2015-01-01   62.062779
# 3                2015-01-05   96.542222
# 4                2015-01-06  103.926154
# ..                      ...         ...
# 897              2017-12-04  148.121613
# 898              2017-12-05  118.205000
# 899              2017-12-06  178.939535
# 900              2017-12-07  173.704444
# 901              2017-12-08  198.000000
#
# [902 rows x 2 columns]

# %%
not_cancelled_data=df[df['is_canceled']==0]
not_cancelled_data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
not_cancelled_df_adr=not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values(by='reservation_status_date',inplace=True)
not_cancelled_df_adr
# Out:
#     reservation_status_date         adr
# 0                2015-01-07   31.650000
# 1                2015-01-08  138.444565
# 2                2015-01-09  110.008657
# 3                2015-01-10   86.723818
# 4                2015-01-11   59.627576
# ..                      ...         ...
# 800              2017-12-05  113.367857
# 801              2017-12-06  127.924490
# 802              2017-12-07  130.153945
# 803              2017-12-08  161.916864
# 804              2017-12-09  153.570000
#
# [805 rows x 2 columns]

# %%
plt.figure(figsize=(20,8))
plt.title("Average daily rate",size=30)

plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label='cancelled')
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'],label='not cancelled')
plt.legend(fontsize=20)

# %%
cancelled_df_adr=cancelled_df_adr[(cancelled_df_adr['reservation_status_date']>'2016') & (cancelled_df_adr['reservation_status_date']<'2017-09')]         
not_cancelled_df_adr=not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date']>'2016') & (not_cancelled_df_adr['reservation_status_date']<'2017-09')]
plt.figure(figsize=(20,8))
plt.title("Average daily rate",size=20)

plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label='cancelled')
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'],label='not cancelled')
plt.legend(fontsize=20)

# %% [markdown]
# # conclution
#
# 1.City hotel reservation is high as well cacellation is also high. the cacellation of city hotel
#   is 41% but for resort hotel reservation is low as compare to city hotel and cancellation is 27%.
#
#
# 2.Resort hotel costly as compare to city hotel.
#
#
# 3.Average daily rates of resort hotel is high compare to city hotel.In weekend or holiday resort
#   hotel average price suddenly do increase.
#
#
# 4.Number of reservation is highest in august month and highest cancellation rate is in january
#   month.
#
#
# 5.January month Adr is high and cancellation rate is high as well as august month adr is low and
#   reservation is high.
#
#
# 6.portugal has highest number of reservation cancelled that is 70%.
#
#
# 7.When adr is increased then reservation cancelled is increased.if hotel wants to increase reservation
#   they should decrease the adr.
